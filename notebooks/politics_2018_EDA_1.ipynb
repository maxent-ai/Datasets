# %%
# %matplotlib inline
# %xmode plain
# %store -r __std_imports
# Out:
# Exception reporting mode: Plain

# %%
__std_imports
# Out:
# importing os, re, pathlib, numpy, pandas and tqdm.

# %%
import pandas_profiling as pp
from pprint import pprint
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white", context="notebook")

# %%
df = pd.read_csv("../data/indian_political_news_2018_dataset/indian_politics_news_2018.csv")

# %% [markdown]
# ### Descriptive stats of our dataset.

# %%
pp.describe(df)["table"]
# Out:
# {'n': 15346,
#  'nvar': 7,
#  'total_missing': 0.004486976596972688,
#  'n_duplicates': 0,
#  'memsize': '839.3 KiB',
#  'recordsize': '56.0 B',
#  'NUM': 0,
#  'DATE': 0,
#  'CONST': 0,
#  'CAT': 4,
#  'UNIQUE': 3,
#  'CORR': 0,
#  'RECODED': 0,
#  'BOOL': 0,
#  'UNSUPPORTED': 0,
#  'REJECTED': 0}

# %%
pp.describe(df)["variables"]
# Out:
#          count distinct_count  p_missing n_missing p_infinite n_infinite  \
# author   15346           1612          0         0          0          0
# content  15346          15346          0         0          0          0
# date     15346            334          0         0          0          0
# tag      14864          13140  0.0314088       482          0          0
# title    15346          15346          0         0          0          0
# url      15346          15346          0         0          0          0
# website  15346              7          0         0          0          0
#
#         is_unique                                               mode  \
# author      False                                                PTI
# content      True  Tulsi Gabbard, the first Hindu lawmaker from H...
# date        False                                         2018-05-15
# tag         False                                                Law
# title        True  Tulsi Gabbard: Hindu War Veteran US Lawmaker M...
# url          True  https://www.thequint.com/news/world/tulsi-gabb...
# website     False                                          firstpost
#
#             p_unique memorysize    type         top  freq
# author      0.105044     122848     CAT         PTI  2422
# content            1     122848  UNIQUE         NaN   NaN
# date       0.0217646     122848     CAT  2018-05-15   117
# tag         0.856249     122848     CAT         Law   251
# title              1     122848  UNIQUE         NaN   NaN
# url                1     122848  UNIQUE         NaN   NaN
# website  0.000456145     122848     CAT   firstpost  5621

# %%
author_frequency = pp.describe(df)["freq"]["author"]
date_frequency = pp.describe(df)["freq"]["date"]
website_frequency = pp.describe(df)["freq"]["website"]

# %%
def count_plot(data, figsize=(20,5), alpha=0.9, palette="ch:5.1,.95,dark=.10", xlabel="none", fontsize=14, labelsize=15, rotation=0):
    plt.figure(figsize=figsize)
    sns.barplot(data.index, data.values, alpha=alpha, palette=palette).tick_params(labelsize=labelsize)
    plt.xticks(rotation=rotation)
    plt.ylabel("FREQUENCY", fontsize=fontsize)
    plt.xlabel(xlabel, fontsize=fontsize)
    plt.show()

# %%
count_plot(website_frequency, xlabel="WEBSITE")

# %%
count_plot(date_frequency.head(80), xlabel="DATE", labelsize=15, rotation=90)

# %%
#top 40 authors
count_plot(author_frequency.head(40), xlabel="AUTHOR", labelsize=15, rotation=90, palette="ch:9.1,.80,dark=.45")

